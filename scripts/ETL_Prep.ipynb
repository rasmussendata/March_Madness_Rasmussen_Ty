# %% [markdown]
# # Import

# %%
# Load all modules needed for EDA
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from scipy import stats
#from sklearn.preprocessing import LabelEncoder
#from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
#from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# %%
# Create path

path = r'/Users/tyrasmussen/Desktop/FVTC/Spring 2026/Data Analytics Capstone/MM/MM Data/FINAL'

# %%
# Import cleaned/validated pickle file
df = pd.read_pickle(os.path.join(path, 'FINAL_Valid_MMData.pkl'))

# %% [markdown]
# # Inspect data structure

# %%
df.head()
# Out:
#    season          team_name  efgpct_off  topct_off  orpct_off  ftrate_off  efgpct_def  topct_def  orpct_def  ftrate_def conference  adjusted_temo  raw_tempo  adjusted_offensive_efficiency  raw_offensive_efficiency  adjusted_defensive_efficiency  raw_defensive_efficiency  avg_possession_length_(offense)  avg_possession_length_(defense)  avgheight  centerheight  pfheight  sfheight  sgheight  pgheight  effectiveheight  experience  bench  centerpts  pfpts  sfpts  sgpts  pgpts  centeror   pfor   sfor   sgor   pgor  centerdr   pfdr   sfdr   sgdr   pgdr     fg2pct     fg3pct      ftpct   blockpct  oppfg2pct  oppfg3pct   oppftpct  oppblockpct    fg3rate  oppfg3rate      arate   opparate   stlrate  oppstlrate       dfp    nstrate  oppnstrate      offft   off2ptfg   off3ptfg      defft   def2ptfg   def3ptfg  seed    tempo  adjtempo        oe     adjoe       de     adjde     adjem post-season_tournament tournament_winner tournament_championship? final_four? top_12_in_ap_top_25_during_week_6?
# ...

# %%
df.shape
# Out:
# (10111, 79)

# %%
# Print column names and data types for sql
print(df.dtypes)
# Out:
# season                                  int64
# team_name                              object
# efgpct_off                            float64
# topct_off                             float64
# orpct_off                             float64
# ftrate_off                            float64
# efgpct_def                            float64
# topct_def                             float64
# orpct_def                             float64
# ftrate_def                            float64
# conference                             object
# adjusted_temo                         float64
# raw_tempo                             float64
# adjusted_offensive_efficiency         float64
# raw_offensive_efficiency              float64
# adjusted_defensive_efficiency         float64
# raw_defensive_efficiency              float64
# avg_possession_length_(offense)       float64
# avg_possession_length_(defense)       float64
# avgheight                             float64
# ...

# %%
df.head()
# Out:
#    season          team_name  efgpct_off  topct_off  orpct_off  ftrate_off  efgpct_def  topct_def  orpct_def  ftrate_def conference  adjusted_temo  raw_tempo  adjusted_offensive_efficiency  raw_offensive_efficiency  adjusted_defensive_efficiency  raw_defensive_efficiency  avg_possession_length_(offense)  avg_possession_length_(defense)  avgheight  centerheight  pfheight  sfheight  sgheight  pgheight  effectiveheight  experience  bench  centerpts  pfpts  sfpts  sgpts  pgpts  centeror   pfor   sfor   sgor   pgor  centerdr   pfdr   sfdr   sgdr   pgdr     fg2pct     fg3pct      ftpct   blockpct  oppfg2pct  oppfg3pct   oppftpct  oppblockpct    fg3rate  oppfg3rate      arate   opparate   stlrate  oppstlrate       dfp    nstrate  oppnstrate      offft   off2ptfg   off3ptfg      defft   def2ptfg   def3ptfg  seed    tempo  adjtempo        oe     adjoe       de     adjde     adjem post-season_tournament tournament_winner tournament_championship? final_four? top_12_in_ap_top_25_during_week_6?
# ...

# %%
# Find numerical values outside of expected ranges of 0 - 100, besides the 'season' column which is expected to have values greater than 100
#numerical_cols = df.select_dtypes(include=[np.number]).columns  
#for col in numerical_cols:
 #   out_of_range = df[(df[col] < 0) | (df[col] > 100)]
  #  if not out_of_range.empty:
   #     print(f"Column '{col}' has values outside the range of 0 to 100:")
    #    print(out_of_range[[col]])

# %%
# Download pickle file to csv for SQL
df.to_csv(os.path.join(path, 'FINAL_Valid_MMData.csv'), index=False)

# %% [markdown]
# # Create new format for SQL transfer

# %%
# conferences

#conferences_df = (
   # df[['conference']]
  #  .drop_duplicates()
 #   .reset_index(drop=True)
#)

#conferences_df['conference_id'] = conferences_df.index + 1

# %%
# Teams
#teams_df = df[['team_name','conference']].drop_duplicates()

#teams_df = teams_df.merge(
 #   conferences_df,
  #  on='conference',
   # how='left'
#)

#teams_df = teams_df[['team_name','conference_id']]

#teams_df['team_id'] = teams_df.index + 1

# %%
# Season
#seasons_df = df[['season']].drop_duplicates().reset_index(drop=True)

#seasons_df['season_id'] = seasons_df.index + 1

# %%
# Connect to relational keys
#df = df.merge(teams_df[['team_id','team_name']], on='team_name')

#df = df.merge(seasons_df[['season_id','season']], on='season')

# %%
# Tournament Results
#tournament_df = df[[
   # 'team_id',
    #'season_id',
    #'seed',
    #'post-season_tournament',
    #'tournament_winner',
    #'tournament_championship?',
    #'final_four?',
    #'top_12_in_ap_top_25_during_week_6?'
#]].copy()

# %%
#from sqlalchemy import create_engine

#server = 'ETL10'
#database = 'March_Madness'

#connection_string = f"mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"

#engine = create_engine(connection_string)

# %%
#df.to_sql("staging_team_data", engine, if_exists="replace", index=False)
